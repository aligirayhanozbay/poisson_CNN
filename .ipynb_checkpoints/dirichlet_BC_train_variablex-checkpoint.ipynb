# %%
import tensorflow as tf
from Dirichlet_BC_NN import *#Dirichlet_BC_NN, Dirichlet_BC_NN_2
from Lp_integral_norm import Lp_integral_norm
from generate_laplace_soln import generate_laplace_soln
import numpy as np
import matplotlib.pyplot as plt
tf.keras.backend.set_floatx('float32')

# %%
#mod = Dirichlet_BC_NN()
mod = Dirichlet_BC_NN_2C(data_format = 'channels_first', mse_component_weight = 1e+1, n_sepconvblocks=5)
mod((tf.random.uniform((10,1,74), dtype = tf.keras.backend.floatx()), tf.random.uniform((10,1), dtype = tf.keras.backend.floatx()), tf.constant(np.random.randint(48,96))))
from IPython.display import clear_output
clear_output()
#mod.load_weights('Dirichlet_BC_NN_variablex.h5')
#mod = Dirichlet_BC_NN_3()

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4)

# %%
def dataset_generator():
    batch_size = 75
    while True:
        nx = np.random.randint(64,85)
        ny = np.random.randint(64,85)
#         print('------------------------')
#         print('generated data shape: ' + str(nx) + ' ' + str(ny) + '\n')
#         model.x_output_resolution = nx
#         print('x output res from generator: ' + str(model.x_output_resolution) + '\n')
        boundaries, soln, dx = generate_laplace_soln(batch_size=batch_size, nonzero_boundaries=['left'], smoothness=np.random.randint(5,20), nx = nx, ny = ny)
#         print('soln shape: ' + str(soln.shape))
        yield [boundaries['left'], dx * tf.ones((soln.shape[0],1), dtype = 'float64'), tf.constant(nx)], soln

# %%
cb = [tf.keras.callbacks.ModelCheckpoint('Dirichlet_BC_NN_variablex.h5', monitor='mse', verbose=1, save_best_only=True, save_weights_only=True), tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', min_lr = 1e-15, verbose = True, patience = 3)]
mod.compile(loss = mod.integral_loss, optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3), metrics = ['mse', 'mae'])
mod.run_eagerly = True
mod.fit_generator(generator=dataset_generator(), steps_per_epoch=200, epochs=5000, validation_data=dataset_generator(), validation_steps=3, callbacks=cb)
# Out:
# Epoch 1/5000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b22c20a5cff8> in <module>
#       2 mod.compile(loss = mod.integral_loss, optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3), metrics = ['mse', 'mae'])
#       3 mod.run_eagerly = True
# ----> 4 mod.fit_generator(generator=dataset_generator(), steps_per_epoch=200, epochs=5000, validation_data=dataset_generator(), validation_steps=3, callbacks=cb)
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1513         shuffle=shuffle,
#    1514         initial_epoch=initial_epoch,
# -> 1515         steps_name='steps_per_epoch')
#    1516
#    1517   def evaluate_generator(self,
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     255
#     256       is_deferred = not model._is_compiled
# --> 257       batch_outs = batch_function(*batch_data)
#     258       if not isinstance(batch_outs, list):
#     259         batch_outs = [batch_outs]
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1245           sample_weights=sample_weights,
#    1246           reset_metrics=reset_metrics,
# -> 1247           output_loss_metrics=self._output_loss_metrics)
#    1248     else:
#    1249       if not isinstance(K.symbolic_learning_phase(), int):
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, reset_metrics, output_loss_metrics)
#     293           sample_weights=sample_weights,
#     294           training=True,
# --> 295           output_loss_metrics=output_loss_metrics))
#     296   if not isinstance(outs, list):
#     297     outs = [outs]
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     233               output_loss_metrics=output_loss_metrics,
#     234               sample_weights=sample_weights,
# --> 235               training=training))
#     236       if total_loss is None:
#     237         raise ValueError('The model cannot be run '
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_eager.py in _model_loss(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     150           current_loss_reduction = loss_fn.reduction
#     151           loss_fn.reduction = losses_utils.ReductionV2.NONE
# --> 152           weighted_losses = loss_fn(targets[i], outs[i], sample_weight=weights)
#     153           loss_fn.reduction = current_loss_reduction
#     154
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/losses.py in __call__(self, y_true, y_pred, sample_weight)
#      94     with ops.name_scope(scope_name, format(self.__class__.__name__),
#      95                         (y_pred, y_true, sample_weight)):
# ---> 96       losses = self.call(y_true, y_pred)
#      97       return losses_utils.compute_weighted_loss(
#      98           losses, sample_weight, reduction=self.reduction)
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/keras/losses.py in call(self, y_true, y_pred)
#     156       Loss values per sample.
#     157     """
# --> 158     return self.fn(y_true, y_pred, **self._fn_kwargs)
#     159
#     160   def get_config(self):
#
# /media/DATA1/ali/poisson_CNN/Dirichlet_BC_NN.py in integral_loss(self, y_true, y_pred)
#     274         index_combinations = tf.Variable(tf.zeros((quadpts.shape[0], quadpts.shape[1], 4 , 2), dtype = tf.int32), trainable = False, dtype = tf.int32) #array storing the 4 index combinations on the original grid which surround each quad. pt.
#     275         corners = tf.Variable(tf.zeros((quadpts.shape[0], quadpts.shape[1], 2 , 2), dtype = np.int32), dtype = tf.int32, trainable = False) #array storing the lower left corner and the upper right corner of each box stored in index_combinations. effectively this will contain [[xmin,ymin],[xmax,ymax]] for the rectangle around each quad pt.
# --> 276         s=tf.constant(indices)
#     277         for i in range(self.n_quadpts):
#     278             for j in range(self.n_quadpts):
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     243   """
#     244   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 245                         allow_broadcast=True)
#     246
#     247
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     251   ctx = context.context()
#     252   if ctx.executing_eagerly():
# --> 253     t = convert_to_eager_tensor(value, ctx, dtype)
#     254     if shape is None:
#     255       return t
#
# ~/.conda/envs/tf-nightly/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     112     return t
#     113   else:
# --> 114     return ops.EagerTensor(value, handle, device, dtype)
#     115
#     116
#
# ValueError: Can't convert non-rectangular Python sequence to Tensor.

# %%
#i = dataset_generator()
inp, soln = next(i)

# %%
b, soln, dx = generate_laplace_soln(batch_size=75, nonzero_boundaries=['left'], smoothness=np.random.randint(5,20), nx = 64, ny = 64)

# %%
x, y = np.meshgrid(np.linspace(0, soln.shape[-2]*inp[1][0,0], soln.shape[-2]), np.linspace(0, soln.shape[-1]*inp[1][0,0], soln.shape[-1]), indexing = 'ij')
p_r = np.random.randint(0,soln.shape[0])
z = mod(inp)[p_r,0,...]
#z = mod(tf.expand_dims(b['left'], axis = 1))[p_r,0,...]
#z = tf.divide(mod([tf.expand_dims(b['left'], axis = 1), dx * tf.ones((soln.shape[0],1), dtype = 'float64')])[p_r,0,...]-soln[p_r,0,...], soln[p_r,0,...])
z_min, z_max = -np.abs(z).max(), np.abs(z).max()
fig, ax = plt.subplots()
c = ax.pcolormesh(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('result')
ax.axis([x.min(), x.max(), y.min(), y.max()])
fig.colorbar(c, ax=ax)

plt.show()

# %%
x, y = np.meshgrid(np.linspace(0, soln.shape[-2]*inp[1][0,0], soln.shape[-2]), np.linspace(0, soln.shape[-1]*inp[1][0,0], soln.shape[-1]), indexing = 'ij')
#p_r = np.random.randint(0,soln.shape[0])
z = soln[p_r,0,...]
#z = mod([tf.expand_dims(b['left'], axis = 1), dx * tf.ones((soln.shape[0],1), dtype = 'float64')])[p_r,0,...]
#z = mod(tf.expand_dims(b['left'], axis = 1))[p_r,0,...]
#z = mod(tf.expand_dims(b['left'], axis = 1))[p_r,0,...]-soln[p_r,0,...]
z_min, z_max = -np.abs(z).max(), np.abs(z).max()
fig, ax = plt.subplots()
c = ax.pcolormesh(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('result')
ax.axis([x.min(), x.max(), y.min(), y.max()])
fig.colorbar(c, ax=ax)

plt.show()

# %%
x, y = np.meshgrid(np.linspace(0, soln.shape[-2]*dx, soln.shape[-2]-1), np.linspace(0, soln.shape[-1]*dx, soln.shape[-1]-1), indexing = 'ij')
#p_r = np.random.randint(0,soln.shape[0])
#z = soln[p_r,0,...]
print(z.shape)
print(x.shape)
z = mod([tf.expand_dims(b['left'], axis = 1), dx * tf.ones((soln.shape[0],1), dtype = 'float64')])[p_r,0,1:-1,1:-1] - soln[p_r,0,1:-1,1:-1]

#z = mod(tf.expand_dims(b['left'], axis = 1))[p_r,0,...]
#z = mod(tf.expand_dims(b['left'], axis = 1))[p_r,0,...]-soln[p_r,0,...]
z_min, z_max = -np.abs(z).max(), np.abs(z).max()
fig, ax = plt.subplots()
c = ax.pcolormesh(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('result')
ax.axis([x.min(), x.max(), y.min(), y.max()])
fig.colorbar(c, ax=ax)

plt.show()
# Out:
# (95, 96)
# (94, 95)

# %%
plt.plot(z[56,:])

# %%
mod.summary()
# Out:
# Model: "dirichlet_bc_nn_2c"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              multiple                  24
# _________________________________________________________________
# conv1d_1 (Conv1D)            multiple                  336
# _________________________________________________________________
# conv1d_2 (Conv1D)            multiple                  20736
# _________________________________________________________________
# sep_conv_block (SepConvBlock multiple                  7728
# _________________________________________________________________
# sep_conv_block_1 (SepConvBlo multiple                  27168
# _________________________________________________________________
# sep_conv_block_2 (SepConvBlo multiple                  27168
# _________________________________________________________________
# sep_conv_block_3 (SepConvBlo multiple                  27168
# _________________________________________________________________
# sep_conv_block_4 (SepConvBlo multiple                  27168
# _________________________________________________________________
# sep_conv_block_5 (SepConvBlo multiple                  27168
# _________________________________________________________________
# conv2d_6 (Conv2D)            multiple                  6416
# _________________________________________________________________
# conv2d_7 (Conv2D)            multiple                  4812
# _________________________________________________________________
# conv2d_8 (Conv2D)            multiple                  2408
# _________________________________________________________________
# upsample2 (Upsample2)        multiple                  0
# _________________________________________________________________
# conv2d_9 (Conv2D)            multiple                  649
# _________________________________________________________________
# dense (Dense)                multiple                  32
# _________________________________________________________________
# dense_1 (Dense)              multiple                  900
# _________________________________________________________________
# dense_2 (Dense)              multiple                  1616
# =================================================================
# Total params: 181,497
# Trainable params: 181,497
# Non-trainable params: 0
# _________________________________________________________________
